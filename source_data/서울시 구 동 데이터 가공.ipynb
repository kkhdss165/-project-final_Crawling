# %% [markdown]
# ## 지하철 데이터 읽어오기

# %%
import pandas as pd

subway_data = pd.read_csv('./subway_info_address.csv', encoding= 'CP949', index_col= 0, header= 0, engine= 'python')

# %%
subway_address_s = subway_data.주소
subway_address_s
# Out:
# 0               405, 한강대로, 남영동, 동자동, 서울, 04320, 대한민국
# 1               대양빌딩, 서소문로, 소공동, 중구, 서울, 04515, 대한민국
# 2            서울 한양도성, 성북로, 성북동, 성북구, 서울, 02880, 대한민국
# 3             서울한양도성, 성북로, 성북동, 성북구, 서울, 02880, 대한민국
# 4      종로5가, 종로, 종로3가, 종로5·6가동, 종로구, 서울, 03129, 대한민국
#                            ...
# 516              4, 아신역길, 아신리, 양평군, 경기도, 12508, 대한민국
# 517          2, 남한강 자전거길, 오빈리, 양평군, 경기도, 12507, 대한민국
# 518             3, 원덕흑천길, 원덕리, 양평군, 경기도, 12564, 대한민국
# 519           용문, 용문시장7길, 다문리, 양평군, 경기도, 12523, 대한민국
# 520             2, 지평의병로, 지평리, 양평군, 경기도, 12541, 대한민국
# Name: 주소, Length: 521, dtype: object

# %%
## 주소 데이터 확인
for sub_address in subway_address_s:
    print(sub_address)
# Out:
# 405, 한강대로, 남영동, 동자동, 서울, 04320, 대한민국
# 대양빌딩, 서소문로, 소공동, 중구, 서울, 04515, 대한민국
# 서울 한양도성, 성북로, 성북동, 성북구, 서울, 02880, 대한민국
# 서울한양도성, 성북로, 성북동, 성북구, 서울, 02880, 대한민국
# 종로5가, 종로, 종로3가, 종로5·6가동, 종로구, 서울, 03129, 대한민국
# 동대문, 율곡로, 종로5·6가동, 종로구, 서울, 04563, 대한민국
# 신설동, 보문로, 숭인2동, 종로구, 서울, 02586, 대한민국
# 왕산로, 용신동, 동대문구, 서울, 02566, 대한민국
# 214, 왕산로, 전농1동, 동대문구, 서울, 02490, 대한민국
# 동묘앞, 지봉로, 창신1동, 종로구, 서울, 03121, 대한민국
# 을지로입구역 4번 출구, 을지로, 명동, 중구, 서울, 04539, 대한민국
# 양미옥, 충무로, 을지로동, 중구, 서울, 03192, 대한민국
# 55-1, 창경궁로, 을지로동, 주교동, 서울, 04545, 대한민국
# 탄드르, 마른내로, 대지 세운상가군, 광희동, 중구, 서울, 04558, 대한민국
# 신당, 다산로, 2통, 신당동, 중구, 서울, 04569, 대한민국
# 상왕십리, 374, 왕십리로, 35통, 왕십리2동, 성동구, 서울, 04707, 대한민국
# 고산자로14길, 행당1동, 성동구, 서울, 04744, 대한민국
# 206, 왕십리로, 사근동, 성동구, 서울, 04763, 대한민국
# 뚝섬, 18, 아차산로, 성수1가1동, 성동구, 서울, 04793, 대한민국
# 100, 아차산로, 성수2가3동, 성동구, 서울, 04793, 대한민국
# 건대입구역사거리, 건대병원, 능동로, 모진동, 화양동, 광진구, 서울, 05011, 대한민국
# 아차산로, 자양2동, 광진구, 서울, 05026, 대한민국
# 강변, 53, 강변역로, 구의3동, 광진구, 서울, 05116, 대한민국
# ...

# %%
## 서울 시,구,동으로 나누기
import re

for idx,sub_address in enumerate(subway_address_s):
    address_string = re.sub(' ', '', sub_address)
    str_address_s = address_string.split(',')
    if '서울' in str_address_s:  
        si = '서울'
        gu = None
        dong = None
        for str_address in str_address_s[::-1]:
            if gu is None and str_address.endswith('구'):
                gu = str_address
            if dong is None and str_address.endswith('동'):
                dong = str_address
        print(idx, si, gu, dong)
    else:
        print(idx, '')
# Out:
# 0 서울 None 동자동
# 1 서울 중구 소공동
# 2 서울 성북구 성북동
# 3 서울 성북구 성북동
# 4 서울 종로구 종로5·6가동
# 5 서울 종로구 종로5·6가동
# 6 서울 종로구 숭인2동
# 7 서울 동대문구 용신동
# 8 서울 동대문구 전농1동
# 9 서울 종로구 창신1동
# 10 서울 중구 명동
# 11 서울 중구 을지로동
# 12 서울 None 주교동
# 13 서울 중구 광희동
# 14 서울 중구 신당동
# 15 서울 성동구 왕십리2동
# 16 서울 성동구 행당1동
# 17 서울 성동구 사근동
# 18 서울 성동구 성수1가1동
# 19 서울 성동구 성수2가3동
# 20 서울 광진구 화양동
# 21 서울 광진구 자양2동
# 22 서울 광진구 구의3동
# 23 서울 송파구 행정동
# 24 서울 송파구 잠실6동
# 25 서울 송파구 잠실2동
# 26 서울 None 잠실동
# 27 서울 강남구 대치2동
# 28 서울 강남구 삼성동
# 29 서울 강남구 역삼동
# 30 서울 서초구 서초동
# 31 서울 서초구 서초3동
# 32 서울 서초구 서초동
# 33 서울 서초구 방배3동
# 34 서울 동작구 사당1동
# 35 서울 관악구 인헌동
# 36 서울 관악구 행운동
# 37 서울 관악구 청룡동
# 38 서울 관악구 신림동
# 39 서울 관악구 조원동
# 40 서울 영등포구 대림2동
# 41 서울 영등포구 대림2동
# 42 서울 구로구 신도림동
# 43 서울 영등포구 문래동
# 44 서울 영등포구 당산1동
# 45 서울 영등포구 당산2동
# 46 서울 마포구 합정동
# 47 서울 None 동교동
# 48 서울 서대문구 신촌동
# 49 서울 마포구 아현동
# 50 서울 마포구 아현동
# 51 서울 서대문구 충현동
# 52 서울 성동구 용답동
# 53 서울 성동구 용답동
# 54 서울 구로구 신도림동
# 55 서울 양천구 신정7동
# 56 서울 양천구 신정3동
# 57 서울 동대문구 용신동
# 58
# 59 서울 은평구 진관동
# ...

# %% [markdown]
# ### 예외처리 필요
# - 0 서울 None 동자동
# - 12 서울 None 주교동
# - 26 서울 None 잠실동
# - 47 서울 None 동교동
# - 284 서울 None 한강로동

# %%
##데이터 None에 대한 주소 확인
print(subway_address_s[0])
print(subway_address_s[12])
print(subway_address_s[26])
print(subway_address_s[47])
print(subway_address_s[284])
# Out:
# 405, 한강대로, 남영동, 동자동, 서울, 04320, 대한민국
# 55-1, 창경궁로, 을지로동, 주교동, 서울, 04545, 대한민국
# 잠실종합운동장, 25, 올림픽로, 잠실7동, 잠실동, 서울, 05500, 대한민국
# 홀리데이인 익스프레스, 190-1, 신촌로2길, 홍대거리, 서교동, 동교동, 서울, 04056, 대한민국
# 55, 한강대로23길, 한강로동, 한강로3가, 서울, 04377, 대한민국

# %%
##데이터 None에 대한 예외처리
subway_new_address_s = subway_address_s.copy()

subway_new_address_s[0] = '405, 한강대로, 동자동, 용산구, 서울, 04320, 대한민국'
subway_new_address_s[12] = '55-1, 창경궁로, 주교동, 중구, 서울, 04545, 대한민국'
subway_new_address_s[26] = '잠실종합운동장, 25, 올림픽로, 잠실7동, 송파구, 서울, 05500, 대한민국'
subway_new_address_s[47] = '홀리데이인 익스프레스, 190-1, 신촌로2길, 홍대거리, 동교동, 마포구, 서울, 04056, 대한민국'
subway_new_address_s[284] = '55, 한강대로23길, 한강로3가, 한강로동, 용산구, 서울, 04377, 대한민국'

##데이터 None에 대한 주소 확인
print(subway_new_address_s[0])
print(subway_new_address_s[12])
print(subway_new_address_s[26])
print(subway_new_address_s[47])
print(subway_new_address_s[284])
# Out:
# 405, 한강대로, 동자동, 용산구, 서울, 04320, 대한민국
# 55-1, 창경궁로, 주교동, 중구, 서울, 04545, 대한민국
# 잠실종합운동장, 25, 올림픽로, 잠실7동, 송파구, 서울, 05500, 대한민국
# 홀리데이인 익스프레스, 190-1, 신촌로2길, 홍대거리, 동교동, 마포구, 서울, 04056, 대한민국
# 55, 한강대로23길, 한강로3가, 한강로동, 용산구, 서울, 04377, 대한민국

# %%
## 다시 확인
## 서울 시,구,동으로 나누기
import re

sigudong = []

for idx,sub_address in enumerate(subway_new_address_s):
    address_string = re.sub(' ', '', sub_address)
    str_address_s = address_string.split(',')
    temp_str = ''
    if '서울' in str_address_s:  
        si = '서울'
        gu = None
        dong = None
        for str_address in str_address_s[::-1]:
            if gu is None and str_address.endswith('구'):
                gu = str_address
            if dong is None and str_address.endswith('동'):
                dong = str_address
        temp_str = si + ' ' + gu + ' ' + dong
        print(idx, temp_str)
    else:
        print(idx, '')
        
    sigudong.append(temp_str)
# Out:
# 0 서울 용산구 동자동
# 1 서울 중구 소공동
# 2 서울 성북구 성북동
# 3 서울 성북구 성북동
# 4 서울 종로구 종로5·6가동
# 5 서울 종로구 종로5·6가동
# 6 서울 종로구 숭인2동
# 7 서울 동대문구 용신동
# 8 서울 동대문구 전농1동
# 9 서울 종로구 창신1동
# 10 서울 중구 명동
# 11 서울 중구 을지로동
# 12 서울 중구 주교동
# 13 서울 중구 광희동
# 14 서울 중구 신당동
# 15 서울 성동구 왕십리2동
# 16 서울 성동구 행당1동
# 17 서울 성동구 사근동
# 18 서울 성동구 성수1가1동
# 19 서울 성동구 성수2가3동
# 20 서울 광진구 화양동
# 21 서울 광진구 자양2동
# 22 서울 광진구 구의3동
# 23 서울 송파구 행정동
# 24 서울 송파구 잠실6동
# 25 서울 송파구 잠실2동
# 26 서울 송파구 잠실7동
# 27 서울 강남구 대치2동
# 28 서울 강남구 삼성동
# 29 서울 강남구 역삼동
# 30 서울 서초구 서초동
# 31 서울 서초구 서초3동
# 32 서울 서초구 서초동
# 33 서울 서초구 방배3동
# 34 서울 동작구 사당1동
# 35 서울 관악구 인헌동
# 36 서울 관악구 행운동
# 37 서울 관악구 청룡동
# 38 서울 관악구 신림동
# 39 서울 관악구 조원동
# 40 서울 영등포구 대림2동
# 41 서울 영등포구 대림2동
# 42 서울 구로구 신도림동
# 43 서울 영등포구 문래동
# 44 서울 영등포구 당산1동
# 45 서울 영등포구 당산2동
# 46 서울 마포구 합정동
# 47 서울 마포구 동교동
# 48 서울 서대문구 신촌동
# 49 서울 마포구 아현동
# 50 서울 마포구 아현동
# 51 서울 서대문구 충현동
# 52 서울 성동구 용답동
# 53 서울 성동구 용답동
# 54 서울 구로구 신도림동
# 55 서울 양천구 신정7동
# 56 서울 양천구 신정3동
# 57 서울 동대문구 용신동
# 58
# 59 서울 은평구 진관동
# 60 서울 은평구 갈현1동
# ...

# %%
sigudong
# Out:
# ['서울 용산구 동자동',
#  '서울 중구 소공동',
#  '서울 성북구 성북동',
#  '서울 성북구 성북동',
#  '서울 종로구 종로5·6가동',
#  '서울 종로구 종로5·6가동',
#  '서울 종로구 숭인2동',
#  '서울 동대문구 용신동',
#  '서울 동대문구 전농1동',
#  '서울 종로구 창신1동',
#  '서울 중구 명동',
#  '서울 중구 을지로동',
#  '서울 중구 주교동',
#  '서울 중구 광희동',
#  '서울 중구 신당동',
#  '서울 성동구 왕십리2동',
#  '서울 성동구 행당1동',
#  '서울 성동구 사근동',
#  '서울 성동구 성수1가1동',
#  '서울 성동구 성수2가3동',
#  '서울 광진구 화양동',
#  '서울 광진구 자양2동',
#  '서울 광진구 구의3동',
#  '서울 송파구 행정동',
#  '서울 송파구 잠실6동',
#  '서울 송파구 잠실2동',
#  '서울 송파구 잠실7동',
#  '서울 강남구 대치2동',
#  '서울 강남구 삼성동',
#  '서울 강남구 역삼동',
#  '서울 서초구 서초동',
#  '서울 서초구 서초3동',
#  '서울 서초구 서초동',
#  '서울 서초구 방배3동',
#  '서울 동작구 사당1동',
#  '서울 관악구 인헌동',
#  '서울 관악구 행운동',
#  '서울 관악구 청룡동',
#  '서울 관악구 신림동',
#  '서울 관악구 조원동',
#  '서울 영등포구 대림2동',
#  '서울 영등포구 대림2동',
#  '서울 구로구 신도림동',
#  '서울 영등포구 문래동',
#  '서울 영등포구 당산1동',
#  '서울 영등포구 당산2동',
#  '서울 마포구 합정동',
#  '서울 마포구 동교동',
#  '서울 서대문구 신촌동',
#  '서울 마포구 아현동',
#  '서울 마포구 아현동',
#  '서울 서대문구 충현동',
#  '서울 성동구 용답동',
#  '서울 성동구 용답동',
#  '서울 구로구 신도림동',
#  '서울 양천구 신정7동',
# ...

# %% [markdown]
# ### csv 저장

# %%
subway_data = pd.read_csv('./subway_info_address.csv', encoding= 'CP949', index_col= 0, header= 0, engine= 'python')
subway_data['시구동'] = sigudong
subway_data

subway_data.to_csv("./subway_info_sigudong.csv", encoding="cp949", mode='w', index = True)

# %% [markdown]
# ## 버스정류장 데이터 읽어오기

# %%
bus_data = pd.read_csv('./bus_info_address.csv', encoding= 'CP949', index_col= 0, header= 0, engine= 'python')
bus_address_s = bus_data.주소
bus_address_s
# Out:
# 0         171, 한글비석로, 하계1동, 노원구, 서울, 01806, 대한민국
# 1       하계1동사무소, 노원로, 하계1동, 노원구, 서울, 01788, 대한민국
# 2        숭곡초교입구, 월계로, 월곡1동, 성북구, 서울, 02733, 대한민국
# 3         창문여중여고, 월계로, 송중동, 강북구, 서울, 02741, 대한민국
# 4                장위로, 장위1동, 성북구, 서울, 02741, 대한민국
#                           ...
# 8010                                         NaN
# 8011                                         NaN
# 8012                                         NaN
# 8013                                         NaN
# 8014                                         NaN
# Name: 주소, Length: 8015, dtype: object

# %%
## 주소 데이터 확인
for idx,sub_address in enumerate(bus_address_s):
    print(idx, sub_address)
# Out:
# 0 171, 한글비석로, 하계1동, 노원구, 서울, 01806, 대한민국
# 1 하계1동사무소, 노원로, 하계1동, 노원구, 서울, 01788, 대한민국
# 2 숭곡초교입구, 월계로, 월곡1동, 성북구, 서울, 02733, 대한민국
# 3 창문여중여고, 월계로, 송중동, 강북구, 서울, 02741, 대한민국
# 4 장위로, 장위1동, 성북구, 서울, 02741, 대한민국
# 5 장위동그린빌아파트, 월계로, 장위1동, 성북구, 서울, 02744, 대한민국
# 6 월계로, 번3동, 강북구, 서울, 02762, 대한민국
# 7 장월지구, 월계로, 번3동, 강북구, 서울, 01883, 대한민국
# 8 101, 월계로, 월계2동, 노원구, 서울, 01883, 대한민국
# 9 인덕대학교, 12, 초안산로, 월계동, 노원구, 서울, 01878, 대한민국
# 10 월계헬스케어센터, 월계로, 월계3동, 노원구, 서울, 01885, 대한민국
# 11 하계시영아파트, 한글비석로, 하계2동, 노원구, 서울, 01784, 대한민국
# 12 골마을근린공원, 한글비석로, 하계1동, 노원구, 서울, 01806, 대한민국
# 13 하계장미아파트, 한글비석로, 하계2동, 노원구, 서울, 01784, 대한민국
# 14 을지병원, 68, 한글비석로, 하계1동, 하계동, 서울, 01830, 대한민국
# 15 골마을근린공원, 한글비석로, 하계1동, 노원구, 서울, 01806, 대한민국
# 16 세이브존스포츠센터, 노원로, 하계1동, 노원구, 서울, 01791, 대한민국
# 17 노원경찰서, 노원로, 하계1동, 노원구, 서울, 01788, 대한민국
# 18 208, 노원로, 하계1동, 노원구, 서울, 01788, 대한민국
# 19 노원구민체육센터, 노원로, 중계동, 노원구, 서울, 01788, 대한민국
# 20 상명중,고등학교, 동일로210길, 중계동, 노원구, 서울, 01768, 대한민국
# 21 중계건영2차아파트, 덕릉로, 중계동, 노원구, 서울, 01760, 대한민국
# ...

# %%
## 서울 시,구,동으로 나누기
import re
import numpy as np

for idx,sub_address in enumerate(bus_address_s):
    if pd.isna(sub_address):
        address_string =''
    else:
        address_string = re.sub(' ', '', sub_address)
    str_address_s = address_string.split(',')
    if '서울' in str_address_s:  
        si = '서울'
        gu = None
        dong = None
        for str_address in str_address_s[::-1]:
            if gu is None and str_address.endswith('구'):
                gu = str_address
            if dong is None and str_address.endswith('동'):
                dong = str_address
        print(idx, si, gu, dong)
    else:
        print(idx, '')
# Out:
# 0 서울 노원구 하계1동
# 1 서울 노원구 하계1동
# 2 서울 성북구 월곡1동
# 3 서울 강북구 송중동
# 4 서울 성북구 장위1동
# 5 서울 성북구 장위1동
# 6 서울 강북구 번3동
# 7 서울 강북구 번3동
# 8 서울 노원구 월계2동
# 9 서울 노원구 월계동
# 10 서울 노원구 월계3동
# 11 서울 노원구 하계2동
# 12 서울 노원구 하계1동
# 13 서울 노원구 하계2동
# 14 서울 None 하계동
# 15 서울 노원구 하계1동
# 16 서울 노원구 하계1동
# 17 서울 노원구 하계1동
# 18 서울 노원구 하계1동
# 19 서울 노원구 중계동
# 20 서울 노원구 중계동
# 21 서울 노원구 중계동
# 22 서울 노원구 하계1동
# 23 서울 노원구 상계동
# 24 서울 노원구 하계1동
# 25 서울 노원구 하계2동
# 26 서울 노원구 하계2동
# 27 서울 노원구 월계2동
# 28 서울 노원구 월계2동
# 29 서울 강북구 번동
# 30 서울 강북구 번동
# 31 서울 노원구 중계동
# 32 서울 강북구 송중동
# 33 서울 강북구 송중동
# 34 서울 성북구 월곡1동
# 35 서울 성북구 길음2동
# 36 서울 성북구 길음1동
# 37 서울 성북구 돈암1동
# 38 서울 성북구 동선동
# 39 서울 성북구 삼선동
# 40 서울 종로구 혜화동
# 41 서울 노원구 중계2·3동
# 42 서울 종로구 혜화동
# 43 서울 종로구 이화동
# 44 서울 종로구 종로1·2·3·4가동
# 45 서울 종로구 종로5·6가동
# 46 서울 중구 을지로동
# 47 서울 중구 을지로동
# 48 서울 중구 명동
# 49 서울 관악구 보라매동
# 50 서울 중구 소공동
# 51 서울 중구 회현동
# 52 서울 중구 회현동
# 53 서울 용산구 남영동
# 54 서울 용산구 청파동
# 55 서울 용산구 한강로동
# 56
# 57 서울 용산구 한강로동
# 58 서울 용산구 한강로동
# 59 서울 용산구 이촌1동
# 60 서울 용산구 이촌1동
# ...

# %% [markdown]
# ### 예외처리 필요
# - 14 서울 None 하계동
# - 325 서울 None 정릉동
# - 865 서울 None 신림동
# - 970 서울 None 내자동
# - 972 서울 None 정릉동
# - 973 서울 None 정릉동
# - 1119 서울 None 송파동
# - 1256 서울 None 한강로동
# - 1473 서울 구로구 None
# - 1546 서울 None 가산동
# - 1754 서울 None 양평동
# - 1830 서울 구로구 None
# - 1831 서울 구로구 None
# - 2072 서울 None 자양동
# - 2163 서울 None 내자동
# - 2189 서울 None 길음동
# - 2499 서울 None 신당동
# - 2666 서울 송파구 None
# - 2712 서울 None 신천동
# - 2895 서울 None 송파동
# - 2984 서울 None 신림동
# - 3051 서울 구로구 None
# - 3052 서울 구로구 None
# - 3983 서울 None 항동
# - 4305 서울 송파구 None
# - 4567 서울 None 신림동
# - 4733 서울 None 고척동
# - 4781 서울 구로구 None
# - 4783 서울 구로구 None
# - 4784 서울 구로구 None
# - 4786 서울 구로구 None
# - 4874 서울 구로구 None
# - 5107 서울 None 사당동
# - 5108 서울 None 사당동
# - 5227 서울 None 신대방동
# - 5878 서울 None 장위동
# - 5881 서울 None 장위동
# - 5888 서울 None 장위동
# - 5951 서울 None 목동
# - 6027 서울 구로구 None
# - 6150 서울 None 소공동
# - 6526 서울 None 문래동
# - 6919 서울 구로구 None
# - 6921 서울 구로구 None
# - 6922 서울 구로구 None
# - 6923 서울 구로구 None
# - 6924 서울 구로구 None
# - 6926 서울 구로구 None
# - 7037 서울 송파구 None
# - 7041 서울 송파구 None
# - 7043 서울 송파구 None
# - 7049 서울 송파구 None
# - 7130 서울 None 성수2가1동
# - 7504 서울 구로구 None
# - 7954 서울 None 명일동

# %%
##데이터 None에 대한 주소 확인
print(bus_address_s[14])
print(bus_address_s[325])
print(bus_address_s[865])
print(bus_address_s[970])
print(bus_address_s[972])
print(bus_address_s[973])
print(bus_address_s[1119])
print(bus_address_s[1256])
print(bus_address_s[1473])
print(bus_address_s[1546])
print(bus_address_s[1754])
print(bus_address_s[1830])
print(bus_address_s[1831])
print(bus_address_s[2072])
print(bus_address_s[2163])
print(bus_address_s[2189])
print(bus_address_s[2499])
print(bus_address_s[2666])
print(bus_address_s[2712])
print(bus_address_s[2895])
print(bus_address_s[2984])
print(bus_address_s[3051])
print(bus_address_s[3052])
print(bus_address_s[3983])
print(bus_address_s[4305])
print(bus_address_s[4567])
print(bus_address_s[4733])
print(bus_address_s[4781])
print(bus_address_s[4783])
print(bus_address_s[4784])
print(bus_address_s[4786])
print(bus_address_s[4874])
print(bus_address_s[5107])
print(5108,bus_address_s[5108])
print(bus_address_s[5227])
print(bus_address_s[5878])
print(bus_address_s[5881])
print(bus_address_s[5888])
print(bus_address_s[5951])
print(bus_address_s[6027])
print(bus_address_s[6150])
print(bus_address_s[6526])
print(bus_address_s[6919])
print(bus_address_s[6921])
print(bus_address_s[6922])
print(bus_address_s[6923])
print(bus_address_s[6924])
print(bus_address_s[6926])
print(bus_address_s[7037])
print(bus_address_s[7041])
print(bus_address_s[7043])
print(7049,bus_address_s[7049])
print(bus_address_s[7130])
print(bus_address_s[7504])
print(bus_address_s[7954])
# Out:
# 을지병원, 68, 한글비석로, 하계1동, 하계동, 서울, 01830, 대한민국
# 신흥약국, 76, 보국문로, 정릉4동, 정릉동, 서울, 02718, 대한민국
# 은성 온누리 약국, 210, 신림로36길, 서림동, 신림동, 서울, 08845, 대한민국
# 1-5, 사직로12길, 사직동, 내자동, 서울, 03169, 대한민국
# 고려대사대부속중·고등학교, 161, 정릉로, 정릉3동, 정릉동, 서울, 02708, 대한민국
# 고려대사대부속중·고등학교, 161, 정릉로, 정릉3동, 정릉동, 서울, 02708, 대한민국
# 1A상가, 헬리오시티 1A상가, 송파대로, 송파2동, 송파동, 서울, 05698, 대한민국
# 아이파크몰 리빙파크, 55, 한강대로23길, 한강로동, 한강로3가, 서울, 04377, 대한민국
# Garibongsijang, 구로동로, 구로구, 서울, 08510, 대한민국
# W몰, 188, 디지털로, 서울디지털국가산업단지 2단지, 가산동, 서울, 08513, 대한민국
# 신동아아파트2동, 영등포로, 양평동, 양평동1가, 서울, 07279, 대한민국
# 삼부르네상스.효성아파트, 남부순환로, 구로구, 서울, 08393, 대한민국
# 가리봉파출소, 남부순환로, 구로구, 서울, 08393, 대한민국
# 더클래식500, 90, 능동로, 자양3동, 자양동, 서울, 05065, 대한민국
# 114, 사직로, 사직동, 내자동, 서울, 03169, 대한민국
# 세기약국, 235, 동소문로, 길음1동, 길음동, 서울, 02735, 대한민국
# 서울광희초등학교, 296, 다산로, 2통, 신당동, 서울, 04569, 대한민국
# 올림픽대교남단, 강동대로, 송파구, 서울, 05505, 대한민국
# 롯데월드몰, 300, 올림픽로, 잠실6동, 신천동, 서울, 05551, 대한민국
# 1A상가, 헬리오시티 1A상가, 송파대로, 송파2동, 송파동, 서울, 05698, 대한민국
# 84, 복은8길, 서림동, 신림동, 서울, 08840, 대한민국
# ...

# %%
##데이터 None에 대한 예외처리
bus_new_address_s = bus_address_s.copy()

##데이터 None에 대한 예외처리

bus_new_address_s[14] = '을지병원, 68, 한글비석로, 하계1동, 노원구, 서울, 01830, 대한민국'
bus_new_address_s[325] = '신흥약국, 76, 보국문로, 정릉4동, 성북구, 서울, 02718, 대한민국'
bus_new_address_s[865] = '은성 온누리 약국, 210, 신림로36길, 신림동, 관악구, 서울, 08845, 대한민국'
bus_new_address_s[970] = '1-5, 사직로12길, 내자동, 종로구, 서울, 03169, 대한민국'
bus_new_address_s[972] = '고려대사대부속중·고등학교, 161, 정릉로, 정릉3동, 성북구, 서울, 02708, 대한민국'
bus_new_address_s[973] = '고려대사대부속중·고등학교, 161, 정릉로, 정릉3동, 성북구, 서울, 02708, 대한민국'
bus_new_address_s[1119] = '1A상가, 헬리오시티 1A상가, 송파대로, 송파2동, 송파구, 서울, 05698, 대한민국'
bus_new_address_s[1256] = '아이파크몰 리빙파크, 55, 한강대로23길, 한강로3가, 한강로동, 용산구, 서울, 04377, 대한민국'
bus_new_address_s[1473] = 'Garibongsijang, 구로동로, 가리봉동, 구로구, 서울, 08510, 대한민국'
bus_new_address_s[1546] = 'W몰, 188, 디지털로, 서울디지털국가산업단지 2단지, 가산동, 금천구,서울, 08513, 대한민국'
bus_new_address_s[1754] = '신동아아파트2동, 영등포로, 양평동, 양평동1가, 영등포구,서울, 07279, 대한민국'
bus_new_address_s[1830] = '삼부르네상스.효성아파트, 남부순환로, 가리봉동, 구로구, 서울, 08393, 대한민국'
bus_new_address_s[1831] = '가리봉파출소, 남부순환로, 가리봉동, 구로구, 서울, 08393, 대한민국'
bus_new_address_s[2072] = '더클래식500, 90, 능동로, 자양3동, 광진구, 서울, 05065, 대한민국'
bus_new_address_s[2163] = '114, 사직로, 내자동, 종로구, 서울, 03169, 대한민국'
bus_new_address_s[2189] = '세기약국, 235, 동소문로, 길음1동, 성북구, 서울, 02735, 대한민국'
bus_new_address_s[2499] = '서울광희초등학교, 296, 다산로, 2통, 신당동, 중구, 서울, 04569, 대한민국'
bus_new_address_s[2666] = '올림픽대교남단, 강동대로, 풍납동, 송파구, 서울, 05505, 대한민국'
bus_new_address_s[2712] = '롯데월드몰, 300, 올림픽로, 신천동, 송파구, 서울, 05551, 대한민국'
bus_new_address_s[2895] = '1A상가, 헬리오시티 1A상가, 송파대로, 송파2동, 송파구, 서울, 05698, 대한민국'
bus_new_address_s[2984] = '84, 복은8길, 신림동, 관악구, 서울, 08840, 대한민국'
bus_new_address_s[3051] = '구로E마트, 디지털로32길, 구로디지털단지, 구로동, 구로구, 서울, 08379, 대한민국'
bus_new_address_s[3052] = '디지털산업1단지, 디지털로, 구로디지털단지, 구로동, 구로구, 서울, 08389, 대한민국'
bus_new_address_s[3983] = 'A동, 88, 부광로, 항동, 구로구, 서울, 08362, 대한민국'
bus_new_address_s[4305] = '강동대로7길, 풍납동, 송파구, 서울, 05537, 대한민국'
bus_new_address_s[4567] = '신림고등학교, 119, 문성로, 신림동, 관악구, 서울, 08772, 대한민국'
bus_new_address_s[4733] = '고척산업용품종합상가, 42, 경인로43길, 고척1동, 구로구, 서울, 08227, 대한민국'
bus_new_address_s[4781] = '구로3동 주민센터, 109, 디지털로31길, 구로디지털단지, 구로동, 구로구, 서울, 08372, 대한민국'
bus_new_address_s[4783] = '에이스테크노타워2차, 디지털로31길, 구로디지털단지, 구로동, 구로구, 서울, 08372, 대한민국'
bus_new_address_s[4784] = '롯데시티호텔 구로, 300, 디지털로, 구로디지털단지, 구로동, 구로구, 서울, 08377, 대한민국'
bus_new_address_s[4786] = '사조참치, 디지털로32길, 구로디지털단지, 구로동, 구로구, 서울, 08379, 대한민국'
bus_new_address_s[4874] = '시흥대로, 가리봉동, 구로구, 서울, 08395, 대한민국'
bus_new_address_s[5107] = '101, 112, 사당로23길, 래미안이수역로이파크아파트, 사당3동, 동작구, 서울, 07001, 대한민국'
bus_new_address_s[5108] =' 104, 112, 사당로23길, 래미안이수역로이파크아파트, 사당3동, 동작구, 서울, 07001, 대한민국'
bus_new_address_s[5227] = '탑모텔, 26, 대림로, 신대방1동, 동작구, 서울, 07070, 대한민국'
bus_new_address_s[5878] = '관문약국, 177, 장위로, 장위3동, 성북구, 서울, 02770, 대한민국'
bus_new_address_s[5881] = '보람약국, 123, 장위로, 장위2동, 성북구, 서울, 02770, 대한민국'
bus_new_address_s[5888] = '나약국, 1, 장위로15길, 장위1동, 성북구, 서울, 02744, 대한민국'
bus_new_address_s[5951] = '50, 목동중앙북로, 목2동, 양천구, 서울, 07948, 대한민국'
bus_new_address_s[6027] = '대륭포스트타워2차, 디지털로, 구로디지털단지, 구로동, 구로구, 서울, 08377, 대한민국'
bus_new_address_s[6150] = '74, 세종대로, 소공동, 태평로2가, 중구, 서울, 04526, 대한민국'
bus_new_address_s[6526] = '크라운팰리스, 33, 문래로, 문래창작촌, 문래동6가, 문래동, 영등포구, 서울, 07278, 대한민국'
bus_new_address_s[6919] = '대륭포스트타워8차, 디지털로26길, 구로디지털단지, 구로동, 구로구, 서울, 08395, 대한민국'
bus_new_address_s[6921] = '한영캐슬시티, 디지털로26길, 구로디지털단지, 구로동, 구로구, 서울, 08395, 대한민국'
bus_new_address_s[6922] = '서울구로디지털단지우체국, 디지털로26길, 구로디지털단지, 구로3동, 구로구, 서울, 08395, 대한민국'
bus_new_address_s[6923] = 'Burger King, 디지털로32길, 구로디지털단지, 구로동, 구로구, 서울, 08379, 대한민국'
bus_new_address_s[6924] = 'JnK 디지털 타워(JnK Digital Tower), 디지털로30길, 구로디지털단지, 구로동, 구로구, 서울, 08389, 대한민국'
bus_new_address_s[6926] = '만민중앙교회, 디지털로26길, 구로디지털단지, 구로동, 구로구, 서울, 08395, 대한민국'
bus_new_address_s[7037] = '풍납중학교, 강동대로, 풍납동, 송파구, 서울, 05505, 대한민국'
bus_new_address_s[7041] = '서울아산병원, 88, 올림픽로43길, 풍납동, 송파구, 서울, 05505, 대한민국'
bus_new_address_s[7043] = '풍납동강변현대아파트, 풍성로14길, 풍납동, 송파구, 서울, 05522, 대한민국'
bus_new_address_s[7049] = '토성오거리, 풍성로26길, 풍납동, 송파구, 서울, 05537, 대한민국'
bus_new_address_s[7130] = '서울숲한라시그마밸리, 51, 성수이로, 성수2가1동, 성수동2가, 성동구, 서울, 04781, 대한민국'
bus_new_address_s[7504] = '구로E마트, 디지털로32길, 구로디지털단지, 구로동, 구로구, 서울, 08379, 대한민국'
bus_new_address_s[7954] = '주양쇼핑, 고덕로62길, 명일2동, 강동구, 서울, 05269, 대한민국'


##데이터 None에 대한 주소 확인
print(bus_new_address_s[14])
print(bus_new_address_s[325])
print(bus_new_address_s[865]) 
print(bus_new_address_s[970]) 
print(bus_new_address_s[972]) 
print(bus_new_address_s[973]) 
print(bus_new_address_s[1119]) 
print(bus_new_address_s[1256]) 
print(bus_new_address_s[1473]) 
print(bus_new_address_s[1546]) 
print(bus_new_address_s[1754]) 
print(bus_new_address_s[1830]) 
print(bus_new_address_s[1831]) 
print(bus_new_address_s[2072]) 
print(bus_new_address_s[2163]) 
print(bus_new_address_s[2189]) 
print(bus_new_address_s[2499]) 
print(bus_new_address_s[2666]) 
print(bus_new_address_s[2712]) 
print(bus_new_address_s[2895]) 
print(bus_new_address_s[2984]) 
print(bus_new_address_s[3051]) 
print(bus_new_address_s[3052]) 
print(bus_new_address_s[3983]) 
print(bus_new_address_s[4305]) 
print(bus_new_address_s[4567]) 
print(bus_new_address_s[4733]) 
print(bus_new_address_s[4781]) 
print(bus_new_address_s[4783]) 
print(bus_new_address_s[4784]) 
print(bus_new_address_s[4786]) 
print(bus_new_address_s[4874]) 
print(bus_new_address_s[5107]) 
print(bus_new_address_s[5227]) 
print(bus_new_address_s[5878]) 
print(bus_new_address_s[5881]) 
print(bus_new_address_s[5888]) 
print(bus_new_address_s[5951]) 
print(bus_new_address_s[6027]) 
print(bus_new_address_s[6150]) 
print(bus_new_address_s[6526]) 
print(bus_new_address_s[6919]) 
print(bus_new_address_s[6921]) 
print(bus_new_address_s[6922]) 
print(bus_new_address_s[6923]) 
print(bus_new_address_s[6924]) 
print(bus_new_address_s[6926]) 
print(bus_new_address_s[7037]) 
print(bus_new_address_s[7041]) 
print(bus_new_address_s[7043]) 
print(bus_new_address_s[7049]) 
print(bus_new_address_s[7130]) 
print(bus_new_address_s[7504]) 
print(bus_new_address_s[7954])
# Out:
# 을지병원, 68, 한글비석로, 하계1동, 노원구, 서울, 01830, 대한민국
# 신흥약국, 76, 보국문로, 정릉4동, 성북구, 서울, 02718, 대한민국
# 은성 온누리 약국, 210, 신림로36길, 신림동, 관악구, 서울, 08845, 대한민국
# 1-5, 사직로12길, 내자동, 종로구, 서울, 03169, 대한민국
# 고려대사대부속중·고등학교, 161, 정릉로, 정릉3동, 성북구, 서울, 02708, 대한민국
# 고려대사대부속중·고등학교, 161, 정릉로, 정릉3동, 성북구, 서울, 02708, 대한민국
# 1A상가, 헬리오시티 1A상가, 송파대로, 송파2동, 송파구, 서울, 05698, 대한민국
# 아이파크몰 리빙파크, 55, 한강대로23길, 한강로3가, 한강로동, 용산구, 서울, 04377, 대한민국
# Garibongsijang, 구로동로, 가리봉동, 구로구, 서울, 08510, 대한민국
# W몰, 188, 디지털로, 서울디지털국가산업단지 2단지, 가산동, 금천구,서울, 08513, 대한민국
# 신동아아파트2동, 영등포로, 양평동, 양평동1가, 영등포구,서울, 07279, 대한민국
# 삼부르네상스.효성아파트, 남부순환로, 가리봉동, 구로구, 서울, 08393, 대한민국
# 가리봉파출소, 남부순환로, 가리봉동, 구로구, 서울, 08393, 대한민국
# 더클래식500, 90, 능동로, 자양3동, 광진구, 서울, 05065, 대한민국
# 114, 사직로, 내자동, 종로구, 서울, 03169, 대한민국
# 세기약국, 235, 동소문로, 길음1동, 성북구, 서울, 02735, 대한민국
# 서울광희초등학교, 296, 다산로, 2통, 신당동, 중구, 서울, 04569, 대한민국
# 올림픽대교남단, 강동대로, 풍납동, 송파구, 서울, 05505, 대한민국
# 롯데월드몰, 300, 올림픽로, 신천동, 송파구, 서울, 05551, 대한민국
# 1A상가, 헬리오시티 1A상가, 송파대로, 송파2동, 송파구, 서울, 05698, 대한민국
# ...

# %%
## 다시 확인
## 서울 시,구,동으로 나누기
import re

sigudong = []

for idx,sub_address in enumerate(bus_new_address_s):
    if pd.isna(sub_address):
        address_string =''
    else:
        address_string = re.sub(' ', '', sub_address)
    str_address_s = address_string.split(',')
    temp_str = ''
    if '서울' in str_address_s:  
        si = '서울'
        gu = None
        dong = None
        for str_address in str_address_s[::-1]:
            if gu is None and str_address.endswith('구'):
                gu = str_address
            if dong is None and str_address.endswith('동'):
                dong = str_address
        temp_str = si + ' ' + gu + ' ' + dong
        print(idx, temp_str)
    else:
        print(idx, '')
        
    sigudong.append(temp_str)
# Out:
# 0 서울 노원구 하계1동
# 1 서울 노원구 하계1동
# 2 서울 성북구 월곡1동
# 3 서울 강북구 송중동
# 4 서울 성북구 장위1동
# 5 서울 성북구 장위1동
# 6 서울 강북구 번3동
# 7 서울 강북구 번3동
# 8 서울 노원구 월계2동
# 9 서울 노원구 월계동
# 10 서울 노원구 월계3동
# 11 서울 노원구 하계2동
# 12 서울 노원구 하계1동
# 13 서울 노원구 하계2동
# 14 서울 노원구 하계1동
# 15 서울 노원구 하계1동
# 16 서울 노원구 하계1동
# 17 서울 노원구 하계1동
# 18 서울 노원구 하계1동
# 19 서울 노원구 중계동
# 20 서울 노원구 중계동
# 21 서울 노원구 중계동
# 22 서울 노원구 하계1동
# 23 서울 노원구 상계동
# 24 서울 노원구 하계1동
# 25 서울 노원구 하계2동
# 26 서울 노원구 하계2동
# 27 서울 노원구 월계2동
# 28 서울 노원구 월계2동
# 29 서울 강북구 번동
# 30 서울 강북구 번동
# 31 서울 노원구 중계동
# 32 서울 강북구 송중동
# 33 서울 강북구 송중동
# 34 서울 성북구 월곡1동
# 35 서울 성북구 길음2동
# 36 서울 성북구 길음1동
# 37 서울 성북구 돈암1동
# 38 서울 성북구 동선동
# 39 서울 성북구 삼선동
# 40 서울 종로구 혜화동
# 41 서울 노원구 중계2·3동
# 42 서울 종로구 혜화동
# 43 서울 종로구 이화동
# 44 서울 종로구 종로1·2·3·4가동
# 45 서울 종로구 종로5·6가동
# 46 서울 중구 을지로동
# 47 서울 중구 을지로동
# 48 서울 중구 명동
# 49 서울 관악구 보라매동
# 50 서울 중구 소공동
# 51 서울 중구 회현동
# 52 서울 중구 회현동
# 53 서울 용산구 남영동
# 54 서울 용산구 청파동
# 55 서울 용산구 한강로동
# 56
# 57 서울 용산구 한강로동
# 58 서울 용산구 한강로동
# 59 서울 용산구 이촌1동
# 60 서울 용산구 이촌1동
# ...

# %%
bus_data = pd.read_csv('./bus_info_address.csv', encoding= 'CP949', index_col= 0, header= 0, engine= 'python')
bus_data['시구동'] = sigudong
bus_data

bus_data.to_csv("./bus_info_sigudong.csv", encoding="cp949", mode='w', index = True)
